# %%
 print ("rolling a dice\n\n")
 import time
 time.sleep(2) # Sleep for 2 seconds
import random 
 
 
x = "y"
 
while x == "y": 
  
    
    # Gnenerates a random number 
    # between 1 and 6 (including 
    # both 1 and 6) 
    no = random.randint(1,6) 
 
    
    if no == 1: 
        print("[its one (1)]") 
    
    if no == 2: 
        print("[its two (2)]") 
        
    if no == 3: 
        print("[its three (3)]") 
    
    if no == 4: 
        print("[its four (4)]") 
        
    if no == 5: 
        print("[its five (5)]") 
    
    if no == 6: 
        print("[its six (6)]") 
        
    x=input("press y to roll again and n to exit:") 
    # grinning face 
print("bye:-) " " " " please come again ""\U0001f600""\U0001f600""\U0001f44b")
# Out:
# rolling a dice
#
#
# [its four (4)]
# press y to roll again and n to exit:n
# bye:-)   please come again 😀😀👋
