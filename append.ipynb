# %%
x = ['ab','c,d']
for i in x:
  x.append(i.upper())
  print(x)
# Out:
# ['ab', 'c,d', 'AB']
# ['ab', 'c,d', 'AB', 'C,D']
# ['ab', 'c,d', 'AB', 'C,D', 'AB']
# ['ab', 'c,d', 'AB', 'C,D', 'AB', 'C,D']
# ['ab', 'c,d', 'AB', 'C,D', 'AB', 'C,D', 'AB']
# ['ab', 'c,d', 'AB', 'C,D', 'AB', 'C,D', 'AB', 'C,D']
# ['ab', 'c,d', 'AB', 'C,D', 'AB', 'C,D', 'AB', 'C,D', 'AB']
# ['ab', 'c,d', 'AB', 'C,D', 'AB', 'C,D', 'AB', 'C,D', 'AB', 'C,D']
# ['ab', 'c,d', 'AB', 'C,D', 'AB', 'C,D', 'AB', 'C,D', 'AB', 'C,D', 'AB']
# ['ab', 'c,d', 'AB', 'C,D', 'AB', 'C,D', 'AB', 'C,D', 'AB', 'C,D', 'AB', 'C,D']
# ['ab', 'c,d', 'AB', 'C,D', 'AB', 'C,D', 'AB', 'C,D', 'AB', 'C,D', 'AB', 'C,D', 'AB']
# ['ab', 'c,d', 'AB', 'C,D', 'AB', 'C,D', 'AB', 'C,D', 'AB', 'C,D', 'AB', 'C,D', 'AB', 'C,D']
# ['ab', 'c,d', 'AB', 'C,D', 'AB', 'C,D', 'AB', 'C,D', 'AB', 'C,D', 'AB', 'C,D', 'AB', 'C,D', 'AB']
# ['ab', 'c,d', 'AB', 'C,D', 'AB', 'C,D', 'AB', 'C,D', 'AB', 'C,D', 'AB', 'C,D', 'AB', 'C,D', 'AB', 'C,D']
# ...
