# %%
 # writing a file 
 f=open('making a file.txt','w')
 f.write('name = kartikay class = 12  section = A' )
 f.close()

# %%
#reading a text file with read mode
f=open('making a file.txt','r')
print (f.read ())
f.close()
# Out:
# name = kartikay class = 12  section = A

# %%
#reading a file without read mode
f=open('making a file.txt')
print(f.read())
f.close()
# Out:
# name = kartikay class = 12  section = A

# %%
#reading a text file without reading mode (r+) updating mode
f=open('making a file.txt','r+')
print(f.read())
f.write('\nschool name = don bosco sr sec school the name of my school is Don Bosco Sr.Sec. School . the school is dbs')
f.close()
# Out:
# name = kartikay class = 12  section = A
# school name = don bosco sr sec school the name of my school is Don Bosco Sr.Sec. School . the school is dbs

# %%
#reading a text file line wise
f=open('making a file.txt','r')
count=1
for c in f:
  print("count=",count,c)
  count+=1 
f.close()
# Out:
# count= 1 name = kartikay class = 12  section = A

# %%
#reading a text file using a clause for splitting words
with open('making a file.txt','r') as f:
  data=f.readlines()
  for lines in data:
    words=lines.split()
    print(words)
# Out:
# ['name', '=', 'kartikay', 'class', '=', '12', 'section', '=', 'A']

# %%
#reading a text file using a clause for counting no. of words
with open('making a file.txt','r') as f:
  data=f.readlines()
no_of_words=0
for lines in data:
 words=lines.split()
 for word in words:
    no_of_words+=1
    print(word)
    print("The File has Total" ,no_of_words,"words")
# Out:
# name
# The File has Total 1 words
# =
# The File has Total 2 words
# kartikay
# The File has Total 3 words
# class
# The File has Total 4 words
# =
# The File has Total 5 words
# 12
# The File has Total 6 words
# section
# The File has Total 7 words
# =
# The File has Total 8 words
# A
# The File has Total 9 words

# %%
#reading a text file using a clause for counting no. of characters
with open('making a file.txt','r') as f:
  data=f.readlines()
  for lines in data:
    words=lines.split()
    for word in words:
      for c in word:
        print(c)
# Out:
# n
# a
# m
# e
# =
# k
# a
# r
# t
# i
# k
# a
# y
# c
# l
# a
# s
# s
# =
# 1
# 2
# s
# e
# c
# t
# i
# o
# n
# =
# A

# %%
#reading a text file for counting no. of characters in an easy way 
with open('making a file.txt','r') as f:
  c=''
  while 1:
    c=f.read(1)
    if not c:
      break
    print(c,end="")
# Out:
# name = kartikay class = 12  section = A

# %%
#reading a text file for no. of alpabest and digits
with open('making a file.txt','r') as f:
  c=''
  digit=alpha=0
  while 1:
    c=f.read(1)
    if not c:
      break
    if (c.isdigit()):
       digit+=1
    elif (c.isalpha()):
      alpha+=1
print("There is/are Total" ,digit,"digit(s)")
print("There is/are Total" ,alpha,"alphabet(s)")
# Out:
# There is/are Total 2 digit(s)
# There is/are Total 25 alphabet(s)

# %%
#counting the no. of a word (the)
f=open('making a file.txt','r')
data=(f.read ())
no_of_word= data.count("the")
print('the word "the" is comming',no_of_word,'times' )
# Out:
# the word "the" is comming 0 times

# %%
#counting the no. of vovels
f=open('making a file.txt','r')
vowels = set("AEIOUaeiou")
 
 
print('Total no. of "vovels" is/are comming',no_of_vowels,'times' )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-03bc24fdded5> in <module>()
#       4
#       5
# ----> 6 print('Total no. of "vovels" is/are comming',no_of_vowels,'times' )
#
# NameError: name 'no_of_vowels' is not defined
