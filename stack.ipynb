# %% [markdown]
# [1]  s=[]

# %%
print("1.PUSH\n2.POP\n3.DISPLAY\n4.Exit")
choice=int(input("please select any operations mention above"))
if(choice==1):
  data=int(input("PLease enter data for stack"))
  print(data,"Inserted Succesfully")
elif (choice==2):
  if (s==[]):
    print("under flow")
  else:
      data=s.pop()
      print(data, "is removed from stack")
elif choice==3:
  if (s==[]):
    print("stack is empty")
  else:
    print("_"*20)


    for peek in range(len(s)-1,-1):
          print(s[peek])
          print("_"*20,"\n\n\n")
elif choice==4:
  pass
else:
  print("invalid option")
# Out:
# 1.PUSH
# 2.POP
# 3.DISPLAY
# 4.Exit
# please select any operations mention above1
# PLease enter data for stack9000
# 9000 Inserted Succesfully

# %% [markdown]
# s==[
